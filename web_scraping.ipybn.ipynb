# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://books.toscrape.com/"
response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
section = soup.find("section")
print(section)
# Out:
# <section>
# <div class="alert alert-warning" role="alert"><strong>Warning!</strong> This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.</div>
# <div>
# <ol class="row">
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# ...

# %%
articles = section.find_all("article")
print(len(articles))
# Out:
# 20

# %%
print(articles[0])
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
title = articles[0].h3.a["title"]
print(title)
# Out:
# A Light in the Attic

# %%
price = articles[0].find("p", class_="price_color").text
print(price)
# Out:
# Â£51.77

# %%
availability = articles[0].find("p", class_="instock availability").text.strip()
print(availability)
# Out:
# In stock

# %%
books = []

for article in articles:
    title = article.h3.a["title"]
    price = article.find("p", class_="price_color").text
    availability = article.find("p", class_="instock availability").text.strip()

    books.append({
        "Title": title,
        "Price": price,
        "Availability": availability
    })

df = pd.DataFrame(books)
df
# Out:
#                                                 Title    Price Availability
# 0                                A Light in the Attic  Â£51.77     In stock
# 1                                  Tipping the Velvet  Â£53.74     In stock
# 2                                          Soumission  Â£50.10     In stock
# 3                                       Sharp Objects  Â£47.82     In stock
# 4               Sapiens: A Brief History of Humankind  Â£54.23     In stock
# 5                                     The Requiem Red  Â£22.65     In stock
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34     In stock
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93     In stock
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60     In stock
# 9                                     The Black Maria  Â£52.15     In stock
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99     In stock
# ...

# %%
student_info = [
    "P.SIRISH GOUD",
    "24AG1A05H2",
    "CSE",
    "C",
    "DA"
]

for i in range(len(student_info), len(df)):
    student_info.append("NA")

df.insert(0, "Student Details", student_info)

df
# Out:
#    Student Details                                              Title  \
# 0    P.SIRISH GOUD                               A Light in the Attic
# 1       24AG1A05H2                                 Tipping the Velvet
# 2              CSE                                         Soumission
# 3                C                                      Sharp Objects
# 4               DA              Sapiens: A Brief History of Humankind
# 5               NA                                    The Requiem Red
# 6               NA  The Dirty Little Secrets of Getting Your Dream...
# 7               NA  The Coming Woman: A Novel Based on the Life of...
# 8               NA  The Boys in the Boat: Nine Americans and Their...
# 9               NA                                    The Black Maria
# 10              NA     Starving Hearts (Triangular Trade Trilogy, #1)
# 11              NA                              Shakespeare's Sonnets
# ...

# %%
df.to_csv("books.csv", index=False)
print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Ektha\Desktop\webscraping

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\Ektha\Desktop\webscraping
# ['books.csv', 'python', 'travel_books.csv', 'web_scraping.ipybn.ipynb']

# %%
df.head()
# Out:
#   Student Details                                  Title    Price Availability
# 0   P.SIRISH GOUD                   A Light in the Attic  Â£51.77     In stock
# 1      24AG1A05H2                     Tipping the Velvet  Â£53.74     In stock
# 2             CSE                             Soumission  Â£50.10     In stock
# 3               C                          Sharp Objects  Â£47.82     In stock
# 4              DA  Sapiens: A Brief History of Humankind  Â£54.23     In stock

# %%
df.to_csv("books.csv", index=False)

# %%
import os

print("Current folder:", os.getcwd())
# Out:
# Current folder: c:\Users\Ektha\Desktop\webscraping

# %%
df.to_csv("books.csv", index=False)
print("Saved!")
# Out:
# Saved!
